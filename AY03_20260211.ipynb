# %% [markdown]
# ## Ejercicio 4: (Tarea moral de la ayudantía 2)
#
# Diseñemos un programa para resolver cualquier ecuación de primer grado de la forma
# \begin{equation}
# ax+b=0
# \end{equation}
# donde $x$ es la incógnita. Los pasos a seguir serán:
#
# *Algoritmo*
# 1. Pedir el valor de $a$ y $b$ (dígase que son de tipo flotante).
# 2. Calcular el valor de $x$ como $\frac{-b}{a}$
# 3. Mostrar en pantalla el valor de $x$

# %% [markdown]
# ## F-String
#
# Para especificar una cadena como una f-string, solo hay que colocar una f delante del literal de cadena y agregue llaves {} como marcadores de posición para variables y otras operaciones.

# %%
edad = 24

# sin f-string
print("Yo tengo", edad, "años")

# con f-string
print(f"Yo tengo {edad} años")
# Out:
# Yo tengo 24 años
# Yo tengo 24 años

# %% [markdown]
# tambien se pueden hacer operaciones dentro los marcadores de posición:

# %%
print(f"El precio de ese producto es de: {5*18} pesos mexicanos")
# Out:
# El precio de ese producto es de: 90 pesos mexicanos

# %% [markdown]
# ## Paquetería math

# %%
from math import *
print(pi,sin(pi))
# Out:
# 3.141592653589793 1.2246467991473532e-16

# %%
from math import sqrt
print(sqrt(4))
print((4)**0.5)
# Out:
# 2.0
# 2.0

# %% [markdown]
# Usando un alias para definir a las paqueterías y no escribir todo el nombre

# %%
import math as m

print(m.sqrt(4))
# Out:
# 2.0

# %% [markdown]
# ## Estructuras de control

# %% [markdown]
# ### IF - ELSE
#
# La instrucción if evalúa una condición (una expresión cuyo resultado es Verdadero o Falso ). Si la condición es verdadera, se ejecuta el bloque de código dentro de la instrucción if. Si la condición es falsa, se omite el bloque de código.
#
# Es como decirle a Python *al llegar a este punto, ejecuta esta(s) acción(es) sólo so esta condición es cierta*
#
# ```
# if condición:
#       acción
# ```

# %%
a= 1
b= 2

if b > a:
  print("b es mayor que a")
# Out:
# b es mayor que a

# %% [markdown]
# ### Identación
#
# La sangría se refiere a los espacios al principio de una línea de código.
#
# Mientras que en otros lenguajes de programación la sangría en el código es solo para la legibilidad, la sangría en Python es muy importante.
#
# Python utiliza sangría para indicar un bloque de código.

# %% [markdown]
# Las variables booleanas se pueden utilizar directamente en declaraciones if sin operadores de comparación

# %%
variable = True
if variable:
  print("Hello World!")
# Out:
# Hello World!

# %% [markdown]
# ### Else
#
# La palabra else significa sino o en caso contrario

# %%
a= 2
b= 1

if b < a:
  print("b es menor que a")
else:
  print("b es mayor que a")
# Out:
# b es menor que a

# %%
x=4

if(x%2 == 0):
    print("entera")
else:
    print("El reciduo es distinto de cero")
# Out:
# entera

# %% [markdown]
# ### elif
#
# La palabra clave elif le permite verificar múltiples expresiones para verificar si son Verdaderas y ejecutar un bloque de código tan pronto como una de las condiciones se evalúe como Verdadero  y omite las demás.

# %% [markdown]
# Solo se ejecutará la primera condición verdadera. Incluso si varias condiciones son verdaderas, Python se detiene después de ejecutar el primer bloque coincidente.
#
# Es recomendable usar elif cuando tenga que verificar varias condiciones mutuamente excluyentes.Ya que esto es más eficiente que usar varias sentencias if independientes , ya que Python detiene la verificación al encontrar una condición verdadera.

# %%
edad = 24

if edad < 10:
  print("Eres un niño")
elif edad < 20:
  print("Eres un adolescente")
elif edad < 60:
  print("Eres un adulto")
elif edad >= 60:
  print("Eres un adulto mayor")
# Out:
# Eres un adulto mayor

# %%
a= input('Mascotas: ')
if a=='perro':
  print('wouf')
elif a=='gato': #elif significa casi contrario
  print('miau')
elif a==('conejo'):
  print('mmmm')
elif a=='vaca':
  print('mu')
else:
  print('da un animal valido')
# Out:
# Mascotas: perro
# wouf

# %% [markdown]
# ## Listas

# %% [markdown]
# Las listas guardan un conjunto de datos **ordenados** y **modificables** cuya analogía matematica son los vectores.
# En estas se pueden almacenar cualquier tipo de dato y no es necesario fijar su tamaño previamente como en otros lenguajes de programación.
#
# Las listas se crean utilizando corchetes []

# %%
lista1 = []
print (type(lista1))
# Out:
# <class 'list'>

# %%
lista2 = list() #Esta es la otra forma de definir una lista.

print(type(lista2))
# Out:
# <class 'list'>

# %%
# Ejemplo de listas

numeros = [1, 68, 37, 32, 32.9, 72.5, 1000]
nombres=['Jonathan','Silvia','Ulises','Rosa','Simon']
constantes = [2.71828, 3.1415926535, 1.32471, 9.81]
frutas=["manzana","pera","mango","guayaba","sandia","durazno","melocoton","tuna","fresa","platano","manzana"]

# %%
print(numeros)
print(nombres)
print(constantes)
print(frutas)
# Out:
# [1, 68, 37, 32, 32.9, 72.5, 1000]
# ['Jonathan', 'Silvia', 'Ulises', 'Rosa', 'Simon']
# [2.71828, 3.1415926535, 1.32471, 9.81]
# ['manzana', 'pera', 'mango', 'guayaba', 'sandia', 'durazno', 'melocoton', 'tuna', 'fresa', 'platano', 'manzana']

# %%
len(frutas) #longitud de una lista usamos la función len()
# Out:
# 11

# %% [markdown]
# ### Acceder a los elementos de una lista

# %% [markdown]
# Siempre recordar que python cuenta el cero como el primer elemento de la lista.

# %%
nombres[0]
# Out:
# 'Jonathan'

# %%
nombres[-1]
# Out:
# 'Simon'

# %%
x = [1,2,3,4]
print(x[0] == x[-4])
print(x[1] == x[-3])
# Out:
# True
# True

# %%
print(frutas[3:5])
# Out:
# ['guayaba', 'sandia']

# %%
print(frutas[:5])
# Out:
# ['manzana', 'pera', 'mango', 'guayaba', 'sandia']

# %%
print(frutas[3:])
# Out:
# ['guayaba', 'sandia', 'durazno', 'melocoton', 'tuna', 'fresa', 'platano', 'manzana']

# %%
if "mango" in frutas:
  print("mango forma parte de la lista")
# Out:
# mango forma parte de la lista

# %% [markdown]
# ### Modificar elementos de una lista

# %%
print(frutas)
frutas[1] = "melon"
print(frutas)
# Out:
# ['manzana', 'pera', 'mango', 'guayaba', 'sandia', 'durazno', 'melocoton', 'tuna', 'fresa', 'platano', 'manzana']
# ['manzana', 'melon', 'mango', 'guayaba', 'sandia', 'durazno', 'melocoton', 'tuna', 'fresa', 'platano', 'manzana']

# %%
frutas[5:6] = ["pitaya","ciruela"]
print(frutas)
# Out:
# ['manzana', 'melon', 'mango', 'guayaba', 'sandia', 'pitaya', 'ciruela', 'melocoton', 'tuna', 'fresa', 'platano', 'manzana']

# %% [markdown]
# Se pueden combinar listas... de manera muy sencilla

# %%
listaCombinada = [numeros, constantes]
print(listaCombinada)
# Out:
# [[1, 68, 37, 32, 32.9, 72.5, 1000], [2.71828, 3.1415926535, 1.32471, 9.81]]

# %%
print(listaCombinada[0][0])
# Out:
# 1

# %% [markdown]
# La indexación sólo nos da acceso a un elemento de la lista, existen métodos para poder checar segmentos.

# %%
# help() - checa los detalles de la función.... también puedes usar el signo "?" seguido de la función
help(len)
# Out:
# Help on built-in function len in module builtins:
#
# len(obj, /)
#     Return the number of items in a container.

# %%
len?

# %% [markdown]
# ### **Slicing**
# Se realiza definiendo los valores de índice del primer elemento y el último elemento de la lista principal que se requiere en la lista dividida. Se escribe como [ a : b ] donde a,b son los valores de índice de la lista padre. Si a o b no está definido, entonces el valor del índice se considera el primer valor para a si a no está definido y el último valor para b cuando b no está definido.

# %% [markdown]
# ## Métodos de lista

# %% [markdown]
# **append(a)**: es utilizado para añadir un elemento al final de la lista

# %%
frutas.append(1)

# %% [markdown]
# **extend(lst)** es usada para anidar una lista "lst" en una lista.

# %%
lst1.extend(lst2)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-2662593136.py in <cell line: 0>()
# ----> 1 lst1.extend(lst2)
#
# NameError: name 'lst1' is not defined

# %%
list1 = ["a", "b" , "c"]
list2 = [1, 2, 3]

list3 = list1 + list2
print(list3)
# Out:
# ['a', 'b', 'c', 1, 2, 3]

# %%
y = [1,2,3,4,5,6]
y[-3::2]
# Out:
# [4, 6]

# %%
y[::-1]
# Out:
# [6, 5, 4, 3, 2, 1]

# %% [markdown]
# **index(i)** se utiliza para encontrar el valor de índice de un elemento particular i. Tenga en cuenta que si hay varios elementos del mismo valor, se devuelve el primer valor de índice de ese elemento.

# %%
lst.index(4)
# Out:
# 2

# %% [markdown]
# **insert(a,b)**:  se utiliza para insertar un elemento y en un valor de índice especificado x.

# %%
lst.insert(4,'asus')
# Out:
# [1, 1, 4, 8, 'asus', 7, 1]

# %% [markdown]
# **remove()** Se usa para eliminar elementos de la lista.

# %%
frutas.remove('manzana')
print(lst)
# Out:
# [1, 1, 4, 8, 7, 1]

# %% [markdown]
# **pop()** elimina el índice especificado (o el último elemento si no se especifica el índice).

# %%
lst.pop(2)
# Out:
# 4

# %% [markdown]
# **del** Elimina elementos especificos de una lista, e incluso toda la lista si no se le pasa ningún indice

# %%
del lst[3]
lst
# Out:
# [1, 1, 8, 1]

# %% [markdown]
# **reverse()** Cambia el orden de la lista

# %%
lst.reverse()
print(lst)
# Out:
# [1, 8, 1, 1]

# %% [markdown]
# **sort()** Ordena alfanumericamente ascendente una lista.

# %%
lst.sort()
print(lst)
# Out:
# [1, 1, 1, 8]

# %%
lst.sort(reverse=True)
print(lst)
# Out:
# [8, 1, 1, 1]

# %%
# para una lista de cadenas, usaremos la condición clave nuevamente
names_list.sort(key=len,reverse=True)
print(names_list)
# Out:
# ['rajueatskaju', 'ucalyptus', 'shatadru', 'palspal', 'anitesh']

# %% [markdown]
# **clear**: Vacía la lista, esta aún existe, pero sin contenido.

# %% [markdown]
# **copy()**: copiar una lista.

# %%
frutas2 = frutas.copy() #opción 1

frutas3 = list(frutas) # opción 2

frutas4 = frutas[:] #opción 3

# %%
thislist = ["apple", "banana", "cherry"]
mylist = list(thislist)
print(mylist)
# Out:
# ['apple', 'banana', 'cherry']

# %% [markdown]
# **count()** se usa para contar el número de elementos que están presentes en la lista.

# %%
lst.count(1)
# Out:
# 3

# %% [markdown]
# El programa no funciona bien cuando  a  vale  0 , se produce un error de división entre cero. Para evitar la división entre cero, pondremos un condicional, el cual excluirá el caso en que a=0. Por lo que el programa será:

# %% [markdown]
# Las estructuras de control pueden anidarse, es decir, aparecer unas dentro de otras.

# %%
a=float(input("Valor de a: "))
b=float(input("Valor de b: "))

if a!=0:
    x=-float(b)/a
    print ("Solución: ",x)
if a==0:
    if b!=0:
        print ("La ecuación no tiene solución")
    if b==0:
        print ("La ecuación tiene infinitas soluciones")
print('Adios')

# %% [markdown]
# resolver ecuaciones de segundo grado de la forma
#
# \begin{equation}
#  ax^{2} + bx+c=0
# \end{equation}
# ¿Cuáles son los datos del problema? Los coeficientes $a$, $b$ y $c$. ¿Qué se desea calcular? Los valores de $x$ que hacen cierta la ecuación. Dichos valores son:
#
# \begin{equation}
# x_1=\frac{-b+\sqrt{b^{2}-4ac}}{2a} \qquad
# x_2=\frac{-b-\sqrt{b^{2}-4ac}}{2a}
# \end{equation}
#
# Un problema que debe considerar es la división entre cero que tiene lugar cuando $a$ vale $0$. Tratemos de evitar el problema de la
# división por cero del mismo modo que antes, pero mostrando un mensaje distinto, pues cuando $a$ vale 0 la ecuación no es de segundo grado, sino de primer grado.

# %%
from math import sqrt
a=float(input("Valor de a: "))
b=float(input("Valor de b: "))
c=float(input("Valor de c: "))
if a!=0:
    x1=(-b+(b**2-4*a*c)**0.5)/(2*a)
    x2=(-b-sqrt(b**2-4*a*c))/(2*a)
    print("x1 = ",x1)
    print("x2 = ",x2)
if a==0:
    print ("No es una ecuación de segundo grado, es lineal")
print('Adios')
# Out:
# Valor de a: 1
# Valor de b: 1
# Valor de c: 1
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipython-input-3102305885.py in <cell line: 0>()
#       5 if a!=0:
#       6     x1=(-b+(b**2-4*a*c)**0.5)/(2*a)
# ----> 7     x2=(-b-sqrt(b**2-4*a*c))/(2*a)
#       8     print("x1 = ",x1)
#       9     print("x2 = ",x2)
#
# ValueError: math domain error

# %%
from math import *
a=float(input("Valor de  a: "))
b=float(input("Valor de  b: "))
c=float(input("Valor de  c: "))
if a!=0:
    x1=(-b+sqrt(b**2-4*a*c))/(2*a)
    x2=(-b-sqrt(b**2-4*a*c))/(2*a)
    print("x1 = ",x1)
    print("x2 = ",x2)
else:  # a==0 y es el caso de la ecuación lineal
    if b!=0:
        x=-c/b
        print ("Solución de la ecuación lineal es: x = " %x)
    else:
        if c!=0:
            print ("La ecuación no tiene solución")
        else:
            print ("La ecuación tiene infinidad soluciones")
# Out:
# Valor de  a: 1
# Valor de  b: 1
# Valor de  c: 1
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipython-input-3958245136.py in <cell line: 0>()
#       4 c=float(input("Valor de  c: "))
#       5 if a!=0:
# ----> 6     x1=(-b+sqrt(b**2-4*a*c))/(2*a)
#       7     x2=(-b-sqrt(b**2-4*a*c))/(2*a)
#       8     print("x1 = ",x1)
#
# ValueError: math domain error

# %%
from math import *
a=float(input("Valor de  a: "))
b=float(input("Valor de  b: "))
c=float(input("Valor de  c: "))
if a!=0:  #a!=0, b!=0  c!= o c=0
    x1=(-b+sqrt(b**2-4*a*c))/(2*a)
    x2=(-b-sqrt(b**2-4*a*c))/(2*a)
    print("x1 = ",x1)
    print("x2 = ",x2)
elif b!=0: #a=0, b!=0
    x=-c/b
    print ("Solución de la ecuación lineal es: x = ", x)
elif c!=0: # a=0, b=0
    print ("La ecuacion no tiene solución")
else:  #a=0 b=0 c=0
    print ("La ecuación tiene infinidad soluciones")
# Out:
# Valor de  a: 1
# Valor de  b: 1
# Valor de  c: 1
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipython-input-4197242580.py in <cell line: 0>()
#       4 c=float(input("Valor de  c: "))
#       5 if a!=0:  #a!=0, b!=0  c!= o c=0
# ----> 6     x1=(-b+sqrt(b**2-4*a*c))/(2*a)
#       7     x2=(-b-sqrt(b**2-4*a*c))/(2*a)
#       8     print("x1 = ",x1)
#
# ValueError: math domain error

# %%
from cmath import *
a=float(input("Valor de  a: "))
b=float(input("Valor de  b: "))
c=float(input("Valor de  c: "))
if a!=0:  #a!=0, b!=0  c!= o c=0
    x1=(-b+sqrt(b**2-4*a*c))/(2*a)
    x2=(-b-sqrt(b**2-4*a*c))/(2*a)
    print("x1 = ",x1)
    print("x2 = ",x2)
elif b!=0:
    x=-c/b
    print ("Solución de la ecuación lineal es: x = ", x)
elif c!=0: # a=0, b=0
    print ("La ecuacion no tiene solución")
else:  #a=0 b=0 c=0
    print ("La ecuación tiene infinidad soluciones")
# Out:
# Valor de  a: 1
# Valor de  b: 1
# Valor de  c: 1
# x1 =  (-0.5+0.8660254037844386j)
# x2 =  (-0.5-0.8660254037844386j)

# %% [markdown]
#  Agrega un programa que reciba el radio de un círculo y le despliegue al usuario el siguiente menú:
#
#      Agrega un programa que reciba el radio de un círculo y le despliegue al usuario el siguiente menú:
#
#     A. Calcular el diámetro
#     B. Calcular el perímetro
#     C. Calcular el área
#
# De acuerdo a la opción del resultado, que el programa seleccione el procedimiento y devuelva el resultado.

# %%
from math import pi
print('Programa que cálcula diametro, perimetro y area de un circulo')
r=float(input('Da el radio de tu circulo \t'))
opcion=input('Que quieres calcular? \n A= diametro \n B=perimetro \n C=area\n')
n=opcion.capitalize()
if n=='A':
    print('El diametro es',2*r)
elif n=='B':
    perimetro=pi*(2*r)
    print('El perimetro es: ',perimetro)
elif n=='C':
    area=pi*r**2
    print('El area es: ', area)
else:
    print('Opcion no valida')
# Out:
# Programa que cálcula diametro, perimetro y area de un circulo
# Da el radio de tu circulo 	a
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipython-input-203061105.py in <cell line: 0>()
#       1 from math import pi
#       2 print('Programa que cálcula diametro, perimetro y area de un circulo')
# ----> 3 r=float(input('Da el radio de tu circulo \t'))
#       4 opcion=input('Que quieres calcular? \n A= diametro \n B=perimetro \n C=area\n')
#       5 n=opcion.capitalize()
#
# ValueError: could not convert string to float: 'a'

# %%
#ax+b=0

a=float(input('Da tu coeficiente a: '))
b=float(input('Da tu coeficiente b: '))

if a==0:
  print('No es una ecuación lineal')
else:
  print("x= ", -b/a)
# Out:
# Da tu coeficiente a: 11
# Da tu coeficiente b: 1
# x=  -0.09090909090909091

# %%
#Resolver la ecuación cuadratica
#ax^2 + bx + c

a=float(input('Da tu coeficiente a: '))
b=float(input('Da tu coeficiente b: '))
c=float(input('Da tu coeficiente c: '))

dis=b**2-4*a*c

if a!=0: #and dis<0:
  if dis<0:
    print("La solución no esta en los reales")
  elif dis>0: #elif a!=0 and dis>0:
    print("Hay dos soluciones reales")
    x1=(-b + (dis**(0.5))) / (2*a)
    x2=(-b - (dis**(0.5))) / (2*a)
    print("x1= ", x1)
    print("x2= ", x2)
  elif dis==0:
    print("La solución real es unica")
    x=-b/(2*a)
    print("x= ",x)
elif b!=0:
  print('No es una ecuación cuadática, es una ecuación lineal')
  x= -c/b
  print("x= ",x)
elif c!=0:
  print ('La ecuación no tiene solución')
else:
  print('La ecuación tiene una infinidad de soluciones')
# Out:
# Da tu coeficiente a: 1
# Da tu coeficiente b: 1
# Da tu coeficiente c: 1
# La solución no esta en los reales

# %%
from cmath import *
#programa que resuelve la ecuación a*x**2 +b*x+c =0
a=float(input('Da el coeficiente a \t')) # t es una tabulación, b espacio y n salto de linea
b=float(input('Da el coeficiente b \t'))
c=float(input('Da el coeficiente c \t'))

if a!=0:
  x1=-b + (b**2-4*a*c)**(0.5) / (2*a)
  x2=-b - (b**2-4*a*c)**(0.5) / (2*a)
  #print("x1=%4.3f y x2=%4.3f" %(x1,x2)) # 4 es el número total y 3 el número de cifras significativas
  print('x1= ', x1)
  print('x2= ', x2)
elif b!=0:
  x=-c/b
  print("Solución de la ecuación lineal es %4.3f"%x)
elif c!=0:
  print ('La ecuación no tiene solución')
else:
  print('La ecuación tiene una infinidad de soluciones')
# Out:
# Da el coeficiente a 	1
# Da el coeficiente b 	1
# Da el coeficiente c 	1
# x1=  (-1+0.8660254037844386j)
# x2=  (-1-0.8660254037844386j)
